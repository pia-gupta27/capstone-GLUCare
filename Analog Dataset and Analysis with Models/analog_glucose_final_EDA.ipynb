# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ##Importing Libraries and dataset

# %%
#notes

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
#importing the dataset
dataset = pd.read_csv('final_data.csv')

# %%
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %%
print(X)
# Out:
# [[ 37.1  56.  423. ]
#  [ 34.2  24.  423. ]
#  [ 28.4  29.  423. ]
#  [ 22.6  21.  423. ]
#  [ 23.9  27.  423. ]
#  [ 30.1  23.  423. ]
#  [ 30.1  30.  423. ]
#  [ 24.6  31.  423. ]
#  [ 29.5  22.  423. ]
#  [ 46.8  45.  423. ]
#  [ 24.   23.  423. ]
#  [ 26.2  23.  423. ]
#  [ 27.5  40.  423. ]
#  [ 32.8  45.  423. ]
#  [ 31.1  41.  473. ]
#  [ 22.5  21.  473. ]
#  [ 33.8  31.  473. ]
#  [ 30.   32.  473. ]
#  [ 33.3  28.  473. ]
#  [ 24.3  25.  473. ]
#  [ 28.9  45.  473. ]
#  [ 37.6  51.  473. ]
#  [ 31.6  24.  473. ]
#  [ 33.8  54.  473. ]
#  [ 24.7  21.  473. ]
#  [ 32.3  27.  473. ]
#  [ 27.6  49.  473. ]
#  [ 26.8  69.  477. ]
#  [ 28.   63.  477. ]
#  [ 32.9  23.  477. ]
#  [ 34.4  44.  503. ]
#  [ 32.4  21.  503. ]
#  [ 40.2  37.  568. ]
#  [ 32.9  39.  568. ]
#  [ 32.4  37.  568. ]
#  [ 32.8  45.  568. ]
#  [ 27.   36.  568. ]
#  [ 43.1  33.  489. ]
#  [ 48.8  37.  489. ]
#  [ 24.8  21.  489. ]
#  [ 31.2  30.  489. ]
#  [ 24.2  55.  489. ]
#  [ 33.2  22.  489. ]
# ...

# %%
print(y)
# Out:
# [111 111 111 111 111 111 111 111 111 111 111 111 111 111 125 125 125 125
#  125 125 125 125 125 125 125 125 125 132 132 132 132 132 133 133 133 133
#  133 137 137 137 137 137 137 137 137 139 139 139 139 139 139 139 139 141
#  141 141 141 141 142 142 142 142 142 143 143 143 143 143 143 145 145 145
#  145 145 146 146 146 146 146 146 146 146 146 147 147 147 147 147 147 147
#  151 151 151 151 151 151 153 153 154 154 154 154 154 154 156 156 156 157
#  157 158 158 158 158 158 158 158 158 159 159 162 162 162 162 162 162 163
#  163 163 165 165 165 165 167 167 167 172 174 174 175 175 177 178 179 179
#  179 179 179 183 183 183 184 184 184 186 187 187 187 187 189 189 189 189
#  191 193 193 195 195 196 196 196 199 209 217 220 221 221 224 225 233 234
#  237 241 244 247 248 248 267 272 276 276 301 302 309 310 315 321 350]

# %% [markdown]
# ## EDA - Exploratory Data Analysis

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BMI       171 non-null    float64
#  1   Age       171 non-null    float64
#  2   Voltage   197 non-null    int64
#  3   Glucose   197 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 6.3 KB

# %%
print("Dimensions of the dataset:", dataset.shape)
# Out:
# Dimensions of the dataset: (197, 4)

# %%
dataset.head()
# Out:
#     BMI   Age  Voltage   Glucose
# 0  37.1  56.0       423      111
# 1  34.2  24.0       423      111
# 2  28.4  29.0       423      111
# 3  22.6  21.0       423      111
# 4  23.9  27.0       423      111

# %%
dataset.describe()
# Out:
#               BMI         Age    Voltage      Glucose
# count  171.000000  171.000000  197.000000  197.000000
# mean    33.529825   36.099415  562.065990  165.522843
# std      6.741608   12.674502  120.637087   44.839575
# min     22.100000   21.000000  423.000000  111.000000
# 25%     28.750000   25.000000  495.000000  139.000000
# 50%     32.400000   33.000000  517.000000  154.000000
# 75%     37.750000   44.000000  595.000000  183.000000
# max     53.200000   70.000000  999.000000  350.000000

# %%
#finding missing values
missing_values = dataset.isnull().sum()
missing_values
# Out:
# BMI         26
# Age         26
# Voltage      0
# Glucose      0
# dtype: int64

# %%
#treating missing values
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(X[:, 0:2])
X[:, 0:2] = imputer.transform(X[:, 0:2])
# from scipy import interpolate
# dataset['BMI'] = dataset['BMI'].interpolate(method='linear')
# dataset['Age'] = dataset['Age'].interpolate(method='linear')

# %%
# X = dataset.iloc[:,:-1].values
# y = dataset.iloc[:,-1].values

# %%
print(X[171:,0:2])  #all same values have been added -- 26 values  interpolation -- 42.9   22  mean-- 33.53  36.09
# Out:
# [[33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]
#  [33.52982456 36.0994152 ]]

# %%
# @title Voltage  vs Glucose

from matplotlib import pyplot as plt
dataset.plot(kind='scatter', x='Voltage ', y='Glucose', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title BMI vs Age

from matplotlib import pyplot as plt
dataset.plot(kind='scatter', x='BMI', y='Age', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Glucose vs Voltage

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Glucose']
  ys = series['Voltage ']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = dataset.sort_values('Glucose', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Glucose')
_ = plt.ylabel('Voltage ')

# %%
# @title Glucose

from matplotlib import pyplot as plt
dataset['Glucose'].plot(kind='hist', bins=20, title='Glucose')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title BMI

from matplotlib import pyplot as plt
dataset['BMI'].plot(kind='hist', bins=20, title='BMI')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Age

from matplotlib import pyplot as plt
dataset['Age'].plot(kind='hist', bins=20, title='Age')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
sns.stripplot(x=dataset['Glucose'], color='blue')
plt.xlabel('Blood Glucose Level')
plt.title('Strip Plot of Blood Glucose Level')
plt.show()

# %%
sns.stripplot(x=dataset['Age'], color='blue')
plt.xlabel('Age')
plt.title('Strip Plot of Age')
plt.show()

# %%
sns.stripplot(x=dataset['BMI'], color='blue')
plt.xlabel('BMI')
plt.title('Strip Plot of BMI')
plt.show()
#Underweight: BMI below 18.5
# Normal weight: BMI 18.5 to 24.9
# Overweight: BMI 25 to 29.9
# Obesity (Class I): BMI 30 to 34.9
# Obesity (Class II): BMI 35 to 39.9
# Obesity (Class III): BMI 40 or higher

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute the correlation matrix
corr = dataset.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <Axes: >

# %%
correlation_matrix = dataset.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
sns.pairplot(dataset)
plt.show()

# %%
dataset.hist(figsize=(10,10))
plt.show()

# %%
dataset.plot(kind='box', subplots=True)
plt.show()
