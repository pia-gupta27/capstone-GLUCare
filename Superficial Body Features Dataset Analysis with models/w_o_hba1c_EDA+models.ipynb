# %% [markdown]
# # Data Preprocessing

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
#importing the dataset
dataset = pd.read_csv('glucose1_dia.csv')

# %%
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %%
# Check the data
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16969 entries, 0 to 16968
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       16969 non-null  int64
#  1   Diastolic_Bloo1_Pressure  16969 non-null  int64
#  2   Systolic_Blood_Pressure   16969 non-null  int64
#  3   Heart_Rate                16969 non-null  int64
#  4   Body_Temp                 16969 non-null  float64
#  5   SPO2                      16969 non-null  int64
#  6   Sweating                  16969 non-null  int64
#  7   Shivering                 16969 non-null  int64
#  8   Diabetes                  16969 non-null  int64
#  9   BGL                       16969 non-null  int64
# dtypes: float64(1), int64(9)
# memory usage: 1.3 MB

# %%
dataset.head()
# Out:
#    Age  Diastolic_Bloo1_Pressure  Systolic_Blood_Pressure  Heart_Rate  \
# 0    9                        73                      118          98
# 1    9                        73                      119         102
# 2    9                        76                      110          81
# 3    9                        78                      115          96
# 4   66                        96                      144          92
#
#    Body_Temp  SPO2  Sweating   Shivering   Diabetes  BGL
# 0  98.300707    99          0           0         0   79
# 1  98.300707    94          1           0         0   80
# 2  98.300707    98          1           0         0   70
# 3  98.300707    96          1           0         0   70
# 4  97.807052    98          0           0         0  100

# %%
# @title Diastolic_Bloo1_Pressure

from matplotlib import pyplot as plt
dataset['Diastolic_Bloo1_Pressure'].plot(kind='hist', bins=20, title='Diastolic_Bloo1_Pressure')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Diabetes

from matplotlib import pyplot as plt
import seaborn as sns
dataset.groupby('Diabetes').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Heart_Rate

from matplotlib import pyplot as plt
dataset['Heart_Rate'].plot(kind='hist', bins=20, title='Heart_Rate')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Systolic_Blood_Pressure

from matplotlib import pyplot as plt
dataset['Systolic_Blood_Pressure'].plot(kind='hist', bins=20, title='Systolic_Blood_Pressure')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Age

from matplotlib import pyplot as plt
dataset['Age'].plot(kind='hist', bins=20, title='Age')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df = pd.DataFrame(dataset)
print(df.describe())
# Out:
#                 Age  Diastolic_Bloo1_Pressure  Systolic_Blood_Pressure  \
# count  16969.000000              16969.000000             16969.000000
# mean      30.988862                 77.173493               118.187165
# std       25.585606                  7.241511                 7.700363
# min        9.000000                 60.000000                95.000000
# 25%        9.000000                 71.000000               113.000000
# 50%       14.000000                 76.000000               119.000000
# 75%       55.000000                 83.000000               124.000000
# max       77.000000                 98.000000               145.000000
#
#          Heart_Rate     Body_Temp          SPO2     Sweating     Shivering   \
# count  16969.000000  16969.000000  16969.000000  16969.000000  16969.000000
# mean      91.524191     97.356146     97.382403      0.121692      0.145560
# std       10.409780      0.813555      0.848689      0.326940      0.352674
# ...

# %%
missing_values = df.isnull().sum()

# %%
missing_values
# Out:
# Age                         0
# Diastolic_Bloo1_Pressure    0
# Systolic_Blood_Pressure     0
# Heart_Rate                  0
# Body_Temp                   0
# SPO2                        0
# Sweating                    0
# Shivering                   0
# Diabetes                    0
# BGL                         0
# dtype: int64

# %%
# Print the minimum and maximum of the target variable of glucose level
print("Minimum:", y.min())
print("Maximum:", y.max())
# Out:
# Minimum: 50
# Maximum: 250

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute the correlation matrix
corr = dataset.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %%
dataset.hist(figsize=(10,10))
plt.show()

# %%
# dataset.plot(kind='box', subplots=True)
# plt.show()

# %%
sns.stripplot(x=dataset['BGL'], color='blue')
plt.xlabel('Blood Glucose Level')
plt.title('Strip Plot of Blood Glucose Level')
plt.show()

# %%
sns.stripplot(x=dataset['Age'], color='blue')
plt.xlabel('Age')
plt.title('Strip Plot of Age')
plt.show()

# %%
sns.stripplot(x=dataset['Diastolic_Bloo1_Pressure'], color='blue')
plt.xlabel('Diastolic_Blood_Pressure')
plt.title('Strip Plot of Diastolic_Blood_Pressure')
plt.show()

# %%
sns.stripplot(x=dataset['Systolic_Blood_Pressure'], color='blue')
plt.xlabel('Systolic_Blood_Pressure')
plt.title('Strip Plot of Systolic_Blood_Pressure')
plt.show()

# %%
sns.stripplot(x=dataset['Heart_Rate'], color='blue')
plt.xlabel('Heart_Rate')
plt.title('Strip Plot of Heart Rate')
plt.show()

# %%
sns.stripplot(x=dataset['Body_Temp'], color='blue')
plt.xlabel('Body Temp')
plt.title('Strip Plot of Body Temp')
plt.show()

# %%
sns.stripplot(x=dataset['SPO2'], color='blue')
plt.xlabel('SPO2')
plt.title('Strip Plot of SPO2')
plt.show()

# %%
# Age and Blood Pressure: There is a notable positive correlation between Age and both Diastolic and Systolic Blood Pressure. This suggests that as age increases, both Diastolic and Systolic Blood Pressure tend to increase as well.
# Body Temperature and Age: There is a negative correlation observed between Body Temperature and Age. This could imply that as age increases, body temperature tends to decrease.
# Sweating, Heart Rate, and BGL: Sweating shows a positive correlation with Heart Rate and a negative correlation with Blood Glucose Level (BGL). This might suggest that increased sweating is associated with a higher heart rate and lower blood glucose levels.

# %%
# Age: There doesn’t appear to be a strong correlation between Age and BGL in the heatmap.
# Blood Pressure: Both Diastolic and Systolic Blood Pressure also do not show a strong correlation with BGL.
# Heart Rate: Heart Rate does not seem to have a significant correlation with BGL.
# Body Temperature: Body Temperature also does not show a strong correlation with BGL.
# SPO2: Oxygen Saturation (SPO2) does not appear to have a significant correlation with BGL.
# Sweating: Sweating shows a negative correlation with BGL. This suggests that higher sweating is associated with lower BGL.
# Shivering: Shivering does not appear to have a significant correlation with BGL.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
#Feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ##Deploying models

# %%
#importing ML models from scikit-learn
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
#to save time all models can be applied once using for loop
regressors = {
    'Linear Regression' : LinearRegression(),
    'Decision Tree' : DecisionTreeRegressor(),
    'Random Forest' : RandomForestRegressor(),
    'Support Vector Machines' : SVR(gamma=1),
    'K-nearest Neighbors' : KNeighborsRegressor(n_neighbors=1),
    'XGBoost' : XGBRegressor()
}
results=pd.DataFrame(columns=['MAE','MSE','R2-score'])
for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.round(r2_score(y_test,pred),3)
                         ]

# %% [markdown]
# ## Results table

# %%
results.sort_values('R2-score',ascending=False).style.background_gradient(cmap='Greens',subset=['R2-score'])
# Out:
# <style type="text/css">
# #T_77f84_row0_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_77f84_row1_col2 {
#   background-color: #005924;
#   color: #f1f1f1;
# }
# #T_77f84_row2_col2 {
#   background-color: #005b25;
#   color: #f1f1f1;
# }
# #T_77f84_row3_col2 {
#   background-color: #117b38;
#   color: #f1f1f1;
# }
# #T_77f84_row4_col2 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_77f84_row5_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_77f84" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77f84_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_77f84_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_77f84_level0_col2" class="col_heading level0 col2" >R2-score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77f84_level0_row0" class="row_heading level0 row0" >Random Forest</th>
# ...

# %%
#Applying Random Forest

# %%
#Random forest
from sklearn.ensemble import RandomForestRegressor
regressor1 = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor1.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
y_pred_test = regressor1.predict(X_test)
np.set_printoptions(precision = 2)
print(np.concatenate((y_pred_test.reshape(len(y_pred_test),1),y_test.reshape(len(y_test),1)),1))
# Out:
# [[191.2 102. ]
#  [ 68.   68. ]
#  [ 85.6  77. ]
#  ...
#  [ 66.9  69. ]
#  [ 62.5  61. ]
#  [100.9  80. ]]

# %%
import matplotlib.pyplot as plt

# Assume y_true is your true target values and y_pred is your predicted target values
plt.scatter(y_test, y_pred_test)
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.title('True vs Predicted Values')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assume y_true is your true target values and y_pred is your predicted target values
errors = np.abs(y_test - y_pred_test)

plt.scatter(y_test, y_pred_test, c=errors, cmap='viridis')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k-', color = 'r')
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.title('True vs Predicted Values')
plt.colorbar(label='Absolute Error')
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Assume y_true is your true target values and y_pred is your predicted target values

# Calculate metrics
mae = mean_absolute_error(y_test, y_pred_test)
mse = mean_squared_error(y_test, y_pred_test)
r2 = r2_score(y_test, y_pred_test)

# Print metrics
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"R2 Score: {r2}")
# Out:
# Mean Absolute Error (MAE): 22.70061034445133
# Mean Squared Error (MSE): 1639.9640007347448
# R2 Score: 0.13732554310686962

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = regressor1, X = X_train, y= y_train, cv= 10)
print("Accuracy: {:.2f}%".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f}%".format(accuracies.std()*100))
# Out:
# Accuracy: 13.30%
# Standard Deviation: 3.21%
